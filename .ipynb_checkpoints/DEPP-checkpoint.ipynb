# %% [markdown]
# # DELHI ELCTRICITY CONSUMPTION PREDICTOR

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
elec=pd.read_csv("Consumption with date,weather final CSV.csv")

# %%
elec.head()
elec=elec.set_index('DATE')
elec
# Out:
#                    TIME  temp  rhum   wspd  pres    VALUE
# DATE
# 1/1/2018    12:00:00 AM   6.6   6.6  100.0   0.0  1868.99
# 1/1/2018     3:00:00 AM  10.0  10.0  100.0   0.0  1424.39
# 1/1/2018     6:00:00 AM  13.8  12.4   91.0   0.0  1961.04
# 1/1/2018     9:00:00 AM  19.8  11.0   57.0   0.0  3528.79
# 1/1/2018    12:00:00 PM  16.4  12.7   79.0   0.0  3793.20
# ...                 ...   ...   ...    ...   ...      ...
# 31-12-2018   9:00:00 AM  22.0   7.4   39.0   5.4  3974.57
# 31-12-2018  12:00:00 PM  19.6   8.3   48.0   3.6  4033.06
# 31-12-2018   3:00:00 PM  10.4   8.0   85.0   0.0  3233.93
# 31-12-2018   6:00:00 PM   8.0   7.1   94.0   0.0  3540.88
# 31-12-2018   9:00:00 PM   6.6   6.6  100.0   0.0  2986.59
#
# [2912 rows x 6 columns]

# %%
elec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2912 entries, 1/1/2018 to 31-12-2018
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TIME    2912 non-null   object
#  1   temp    2912 non-null   float64
#  2   rhum    2912 non-null   float64
#  3   wspd    2912 non-null   float64
#  4   pres    2912 non-null   float64
#  5   VALUE   2912 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 159.2+ KB

# %%
elec['pres'].value_counts()
# Out:
# pres
# 0.0       936
# 3.6       293
# 7.6       268
# 5.4       190
# 9.4       155
#          ...
# 1003.9      1
# 1005.8      1
# 1018.1      1
# 1019.6      1
# 51.8        1
# Name: count, Length: 310, dtype: int64

# %%
elec.describe()
# Out:
#               temp         rhum         wspd         pres        VALUE
# count  2912.000000  2912.000000  2912.000000  2912.000000  2912.000000
# mean     25.213805    26.735474    55.126511   244.182555  3659.571071
# std       8.418097    20.247172    33.157776   426.915899  1167.726512
# min       4.200000     4.000000     0.000000     0.000000  1324.520000
# 25%      19.200000    13.500000    23.000000     0.000000  2874.977500
# 50%      26.800000    21.300000    62.000000     7.600000  3535.930000
# 75%      31.400000    27.225000    85.000000    22.300000  4507.440000
# max      44.000000   100.000000   100.000000  1024.300000  6923.770000

# %%
elec.hist(bins=50,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'temp'}>,
#         <Axes: title={'center': 'rhum'}>],
#        [<Axes: title={'center': 'wspd'}>,
#         <Axes: title={'center': 'pres'}>],
#        [<Axes: title={'center': 'VALUE'}>, <Axes: >]], dtype=object)

# %%
elec.isna().sum()
# Out:
# TIME     0
# temp     0
# rhum     0
# wspd     0
# pres     0
# VALUE    0
# dtype: int64

# %%
import missingno as msno
msno.bar(elec)
# Out:
# <Axes: >

# %%
print(elec.head())
print(elec.dtypes)
# Out:
#                  TIME  temp  rhum   wspd  pres    VALUE
# DATE
# 1/1/2018  12:00:00 AM   6.6   6.6  100.0   0.0  1868.99
# 1/1/2018   3:00:00 AM  10.0  10.0  100.0   0.0  1424.39
# 1/1/2018   6:00:00 AM  13.8  12.4   91.0   0.0  1961.04
# 1/1/2018   9:00:00 AM  19.8  11.0   57.0   0.0  3528.79
# 1/1/2018  12:00:00 PM  16.4  12.7   79.0   0.0  3793.20
# TIME      object
# temp     float64
# rhum     float64
# wspd     float64
# pres     float64
# VALUE    float64
# dtype: object

# %%
# Create a copy of the DataFrame
elec_copy = elec.copy()

# Convert TIME column to a numeric format in the copy
elec_copy['TIME_numeric'] = pd.to_datetime(elec_copy['TIME'], format='%I:%M:%S %p').dt.hour * 3600 + pd.to_datetime(elec_copy['TIME'], format='%I:%M:%S %p').dt.minute * 60

# Select numeric columns, including the new TIME_numeric column
elec_numeric = elec_copy.select_dtypes(include=[float]).assign(TIME_numeric=elec_copy['TIME_numeric'])

# Plot the heatmap
plt.figure(figsize=(25, 7))  # Create matplotlib figure
sns.heatmap(elec_numeric.corr(), annot=True, linewidths=1, fmt=".2g", cmap='coolwarm') 
plt.xticks(rotation='horizontal')
plt.title('Correlation Heatmap Including TIME')
plt.show()

# %%
elec=elec.drop('TIME',axis=1)
elec
# Out:
#             temp  rhum   wspd  pres    VALUE
# DATE
# 1/1/2018     6.6   6.6  100.0   0.0  1868.99
# 1/1/2018    10.0  10.0  100.0   0.0  1424.39
# 1/1/2018    13.8  12.4   91.0   0.0  1961.04
# 1/1/2018    19.8  11.0   57.0   0.0  3528.79
# 1/1/2018    16.4  12.7   79.0   0.0  3793.20
# ...          ...   ...    ...   ...      ...
# 31-12-2018  22.0   7.4   39.0   5.4  3974.57
# 31-12-2018  19.6   8.3   48.0   3.6  4033.06
# 31-12-2018  10.4   8.0   85.0   0.0  3233.93
# 31-12-2018   8.0   7.1   94.0   0.0  3540.88
# 31-12-2018   6.6   6.6  100.0   0.0  2986.59
#
# [2912 rows x 5 columns]

# %% [markdown]
# # SPLITTING DATASET INTO TRAINING AND TESTING PART

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(elec,test_size=0.25,random_state=42)
# print(f"Rows in train set- {(train_set)}\nRows in  test set- {(test_set)}")
print(f"Rows in train set- {len(train_set)}\nRows in  test set- {len(test_set)}")
# Out:
# Rows in train set- 2184
# Rows in  test set- 728

# %%
elec_cp=elec.copy()
elec_cp.describe()
# Out:
#               temp         rhum         wspd         pres        VALUE
# count  2912.000000  2912.000000  2912.000000  2912.000000  2912.000000
# mean     25.213805    26.735474    55.126511   244.182555  3659.571071
# std       8.418097    20.247172    33.157776   426.915899  1167.726512
# min       4.200000     4.000000     0.000000     0.000000  1324.520000
# 25%      19.200000    13.500000    23.000000     0.000000  2874.977500
# 50%      26.800000    21.300000    62.000000     7.600000  3535.930000
# 75%      31.400000    27.225000    85.000000    22.300000  4507.440000
# max      44.000000   100.000000   100.000000  1024.300000  6923.770000

# %%
elec=train_set.copy()
elec
# Out:
#             temp  rhum  wspd    pres    VALUE
# DATE
# 6/10/2018   25.4  18.8  67.0     0.0  4055.93
# 22-09-2018  27.4  24.5  84.0    14.8  4215.48
# 13-07-2018  28.4  25.6  85.0     7.6  6031.48
# 6/9/2018    32.2  23.7  61.0    14.8  3523.65
# 30-06-2018  28.0  89.0  11.2   999.6  5344.46
# ...          ...   ...   ...     ...      ...
# 25-07-2018  29.2  27.6  91.0     0.0  5039.48
# 17-05-2018  31.4  17.0  42.0     0.0  4542.40
# 22-05-2018  40.4   9.7  16.0     9.4  3875.48
# 11/6/2018   35.4  45.0   0.0   990.9  5392.52
# 18-04-2018  37.0  17.0  11.2  1003.8  4242.43
#
# [2184 rows x 5 columns]

# %% [markdown]
# # LOOKING FOR CORRELATION AMONG VARIABLES

# %%
corr_matrix=elec.corr()

# %%
corr_matrix['VALUE'].sort_values(ascending=False)
# Out:
# VALUE    1.000000
# temp     0.641467
# rhum     0.194763
# pres     0.092099
# wspd    -0.096824
# Name: VALUE, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes=["VALUE","temp","rhum","pres","wspd"]
scatter_matrix(elec[attributes],figsize=(20,8))
# Out:
# array([[<Axes: xlabel='VALUE', ylabel='VALUE'>,
#         <Axes: xlabel='temp', ylabel='VALUE'>,
#         <Axes: xlabel='rhum', ylabel='VALUE'>,
#         <Axes: xlabel='pres', ylabel='VALUE'>,
#         <Axes: xlabel='wspd', ylabel='VALUE'>],
#        [<Axes: xlabel='VALUE', ylabel='temp'>,
#         <Axes: xlabel='temp', ylabel='temp'>,
#         <Axes: xlabel='rhum', ylabel='temp'>,
#         <Axes: xlabel='pres', ylabel='temp'>,
#         <Axes: xlabel='wspd', ylabel='temp'>],
#        [<Axes: xlabel='VALUE', ylabel='rhum'>,
#         <Axes: xlabel='temp', ylabel='rhum'>,
#         <Axes: xlabel='rhum', ylabel='rhum'>,
#         <Axes: xlabel='pres', ylabel='rhum'>,
#         <Axes: xlabel='wspd', ylabel='rhum'>],
#        [<Axes: xlabel='VALUE', ylabel='pres'>,
#         <Axes: xlabel='temp', ylabel='pres'>,
#         <Axes: xlabel='rhum', ylabel='pres'>,
#         <Axes: xlabel='pres', ylabel='pres'>,
#         <Axes: xlabel='wspd', ylabel='pres'>],
#        [<Axes: xlabel='VALUE', ylabel='wspd'>,
#         <Axes: xlabel='temp', ylabel='wspd'>,
#         <Axes: xlabel='rhum', ylabel='wspd'>,
#         <Axes: xlabel='pres', ylabel='wspd'>,
#         <Axes: xlabel='wspd', ylabel='wspd'>]], dtype=object)

# %%
elec.plot(kind="scatter",x="temp",y="VALUE",alpha=0.8)
# Out:
# <Axes: xlabel='temp', ylabel='VALUE'>

# %%
elec["ppt"]=elec["pres"]/elec["temp"]
# elec_numeric=elec_numeric.drop('TPP',axis=1)
elec = elec.reindex(columns=['temp', 'rhum', 'wspd','pres','ppt','VALUE'])
elec
# Out:
#             temp  rhum  wspd    pres        ppt    VALUE
# DATE
# 6/10/2018   25.4  18.8  67.0     0.0   0.000000  4055.93
# 22-09-2018  27.4  24.5  84.0    14.8   0.540146  4215.48
# 13-07-2018  28.4  25.6  85.0     7.6   0.267606  6031.48
# 6/9/2018    32.2  23.7  61.0    14.8   0.459627  3523.65
# 30-06-2018  28.0  89.0  11.2   999.6  35.700000  5344.46
# ...          ...   ...   ...     ...        ...      ...
# 25-07-2018  29.2  27.6  91.0     0.0   0.000000  5039.48
# 17-05-2018  31.4  17.0  42.0     0.0   0.000000  4542.40
# 22-05-2018  40.4   9.7  16.0     9.4   0.232673  3875.48
# 11/6/2018   35.4  45.0   0.0   990.9  27.991525  5392.52
# 18-04-2018  37.0  17.0  11.2  1003.8  27.129730  4242.43
#
# [2184 rows x 6 columns]

# %%
elec.plot(kind="scatter",x="ppt",y="VALUE",alpha=0.8)
# Out:
# <Axes: xlabel='ppt', ylabel='VALUE'>

# %%
elec=train_set.drop("VALUE",axis=1)
elec_labels=train_set["VALUE"].copy()

# %% [markdown]
# # IMPUTING/FINDING MISSING VALUES AND REPLACING THEM WITH MEDIAN

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="median")
imputer.fit(elec)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([26.9, 21.1, 62. ,  7.6])

# %%
X = imputer.transform(elec)

# %%
elec_tr = pd.DataFrame(X, columns=elec.columns)

# %%
elec_tr.describe()
# Out:
#               temp         rhum         wspd         pres
# count  2184.000000  2184.000000  2184.000000  2184.000000
# mean     25.248626    26.467537    55.428663   239.630952
# std       8.386585    19.960786    32.886153   424.034001
# min       4.200000     4.000000     0.000000     0.000000
# 25%      19.400000    13.500000    25.000000     0.000000
# 50%      26.900000    21.100000    62.000000     7.600000
# 75%      31.400000    27.200000    84.000000    22.300000
# max      44.000000   100.000000   100.000000  1024.300000

# %% [markdown]
# # CREATING A PIPELINE

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    #we can add more pipeline if required
    ('std_scaler',StandardScaler()),
])

# %%
elec_num_tr=my_pipeline.fit_transform(elec)

# %%
elec_num_tr
# Out:
# array([[ 0.01805363, -0.38421796,  0.35194104, -0.56525144],
#        [ 0.25658433, -0.09859267,  0.86899432, -0.53034059],
#        [ 0.37584967, -0.043472  ,  0.89940922, -0.54732425],
#        ...,
#        [ 1.80703386, -0.84021623, -1.19921879, -0.54307833],
#        [ 1.21070711,  0.92865618, -1.68585717,  1.77212464],
#        [ 1.40153167, -0.47441542, -1.34521031,  1.80255369]])

# %%
elec_num_tr.shape
# Out:
# (2184, 4)

# %% [markdown]
# # SELECTING A DESIRED MODEL FOR ELECTRICITY PREDICTION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
# model=LinearRegression()
# model=DecisionTreeRegressor()
model=RandomForestRegressor()
model.fit(elec_num_tr,elec_labels)
# Out:
# RandomForestRegressor()

# %%
some_data=elec.iloc[:100]
# Out:
#             temp  rhum  wspd    pres
# DATE
# 6/10/2018   25.4  18.8  67.0     0.0
# 22-09-2018  27.4  24.5  84.0    14.8
# 13-07-2018  28.4  25.6  85.0     7.6
# 6/9/2018    32.2  23.7  61.0    14.8
# 30-06-2018  28.0  89.0  11.2   999.6
# ...          ...   ...   ...     ...
# 27-09-2018  23.4  22.2  93.0     0.0
# 18-07-2018  29.6  26.6  84.0     0.0
# 1/5/2018    36.4  21.0  41.0     9.4
# 9/3/2018    28.4  11.0  34.0     7.6
# 24-04-2018  23.6  55.0   0.0  1004.6
#
# [100 rows x 4 columns]

# %%
some_labels=elec_labels.iloc[:100]

# %%
prepared_data=my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([4017.386     , 4222.7986    , 5635.3403    , 3754.1434    ,
#        5246.3632    , 3204.7755    , 4397.4947    , 3539.8387    ,
#        3379.0634    , 2243.6337    , 3090.7315    , 3440.7509    ,
#        5142.19915   , 2305.21071667, 2549.7586    , 2411.35228333,
#        2390.568     , 4579.69135096, 4315.9377    , 5269.1341    ,
#        4478.7933    , 4634.3515    , 3363.23274333, 4069.0454    ,
#        5309.8426    , 5076.9469    , 2074.8414    , 5052.8828    ,
#        4628.6564    , 2583.4552825 , 4541.6073    , 2894.7195    ,
#        5418.16665333, 5155.1048    , 3972.4132    , 2939.01666   ,
#        3506.89174   , 3026.2969    , 2435.0274    , 5420.7414    ,
#        1679.762     , 6050.7673    , 2547.99270008, 2626.9792    ,
#        2057.7038    , 3435.637     , 4354.8426    , 4798.78702   ,
#        3592.36425   , 4370.57913333, 2710.65651667, 5205.4074    ,
#        4267.83572667, 5200.3863    , 1951.5932    , 3942.8171    ,
#        5599.3287    , 3290.6153    , 4601.55435   , 2912.557     ,
#        2823.6816    , 1740.7825    , 4609.3281    , 4121.61019333,
#        4728.3946    , 3358.4292    , 5097.01115   , 3029.02895381,
#        5024.9558    , 2640.6362    , 1808.6991    , 4116.4043    ,
#        2022.12005   , 4185.0965    , 3137.4142    , 3134.59958167,
#        5274.6295    , 4171.8045    , 5169.35864167, 2732.6451    ,
#        2425.2713    , 4214.25206667, 2712.9529    , 4716.1155    ,
#        1588.9173    , 4295.949     , 5719.18113333, 5216.14663333,
#        2410.0457    , 4315.3081    , 4751.0322    , 2594.6366    ,
#        2523.4776    , 2293.62149369, 4889.8553    , 3580.5817    ,
#        5329.29960833, 4358.4756    , 2689.4043    , 3900.4514    ])

# %%
list(some_labels)
# Out:
# [4055.93,
#  4215.48,
#  6031.48,
#  3523.65,
#  5344.46,
#  3534.99,
#  4930.72,
#  3542.29,
#  3351.3,
#  1959.0,
#  3148.21,
#  3871.6,
#  5197.37,
#  2114.9,
#  2249.07,
#  2487.83,
#  1886.27,
#  4596.16,
#  4115.83,
#  5161.1,
#  4329.01,
#  4591.25,
#  3378.7,
#  4108.5,
#  5254.16,
#  4923.99,
#  1776.25,
#  5122.91,
#  4730.01,
#  2501.5,
#  4339.25,
#  2946.17,
#  5561.36,
#  5090.0,
#  3946.52,
#  2897.34,
#  3896.77,
#  2990.9,
#  2328.45,
#  5670.23,
#  1496.77,
#  6272.19,
#  2986.59,
#  2620.91,
#  1936.81,
#  3280.49,
#  3885.45,
#  4794.41,
#  3351.11,
#  4372.3,
#  2431.29,
#  5636.59,
#  4422.34,
#  5586.69,
#  1459.91,
#  3960.73,
#  5566.19,
#  3488.36,
#  4886.69,
#  2849.69,
#  2921.06,
#  1449.08,
#  4563.52,
#  3855.47,
#  4644.54,
#  3644.92,
#  5113.82,
#  3349.88,
#  4785.0,
#  2629.97,
#  1497.91,
#  3933.6,
#  1861.46,
#  4638.28,
#  3337.21,
#  3342.89,
#  5278.62,
#  3921.09,
#  5113.94,
#  2972.32,
#  2232.98,
#  3444.84,
#  2812.39,
#  4701.5,
#  1490.87,
#  4295.86,
#  5965.33,
#  5306.76,
#  2120.02,
#  3961.22,
#  4796.77,
#  2629.27,
#  2236.86,
#  3370.54,
#  5047.11,
#  3426.82,
#  5378.05,
#  4505.07,
#  2385.64,
#  3865.83]

# %%
plt.figure(figsize=(20, 8))

# Plot actual values
plt.plot(list(some_labels), label='Actual Values', marker='o')

# Plot predicted values
plt.plot(list(model.predict(prepared_data)), label='Predicted Values', marker='x', linestyle='--')

# Add titles and labels
plt.title('Actual vs Predicted Values')
plt.xlabel('Time Step')
plt.ylabel('Value')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# # EVALUATING THE MODEL

# %%
from sklearn.metrics import mean_squared_error
elec_predictions=model.predict(elec_num_tr)
mse=mean_squared_error(elec_labels,elec_predictions)
rmse=np.sqrt(mse)

# %%
rmse
# Out:
# 281.86842533277803

# %%
# import numpy as np

# Example: Actual and predicted values
actual = elec_labels
predicted =elec_predictions

# Calculate Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((actual - predicted) / actual)) * 100
accuracy = 100 - mape  # Accuracy in percentage

print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 93.14%

# %% [markdown]
# # USING BETTER EVALUATION TECHNIQUE-CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(model,elec_num_tr,elec_labels,scoring="neg_mean_squared_error",cv=10)
rmse_scores=np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([659.99792606, 729.39101957, 691.78150872, 694.55548596,
#        702.15735678, 697.17938099, 656.26394323, 697.90173857,
#        637.72279098, 745.71835671])

# %%
def print_scores(scores):
    print("scores: ",scores)
    print("Mean: ",scores.mean())
    print("S.D: ",scores.std())

# %%
print_scores(rmse_scores)
# Out:
# scores:  [659.99792606 729.39101957 691.78150872 694.55548596 702.15735678
#  697.17938099 656.26394323 697.90173857 637.72279098 745.71835671]
# Mean:  691.266950756848
# S.D:  31.140001829231178

# %% [markdown]
# # TESTING THE MODEL

# %%
X_test=test_set.drop("VALUE",axis=1)
Y_test=test_set['VALUE'].copy()
X_test_prepared=my_pipeline.transform(X_test)
final_predictions=model.predict(X_test_prepared)
final_mse=mean_squared_error(Y_test,final_predictions)
final_rmse=np.sqrt(final_mse)
print(final_rmse)
actual = Y_test
predicted =final_predictions

# Calculate Mean Absolute Percentage Error (MAPE)
mape = np.mean(np.abs((actual - predicted) / actual)) * 100
accuracy = 100 - mape  # Accuracy in percentage

print(f"Accuracy: {accuracy:.2f}%")
# Out:
# 678.923377262358
# Accuracy: 82.57%

# %%
final_rmse
# Out:
# 678.923377262358

# %%
print(final_pred)
# Out:
# [2658.89977333 3252.0885     1993.0689     3506.89174    4974.5212
#  3013.5373     2903.0174     2826.8364     4296.49518    2875.8566
#  5157.1789     2584.2798     3038.3396     5299.0287     5576.376
#  3100.8603     5010.4073     4006.72256667 5343.2744     5061.61981667
#  4197.5672     4957.52816667 4632.7389     4641.90778667 4564.0817
#  4652.0854     2996.48718889 4331.67263333 2680.33997143 5284.0526
#  3053.3057     2392.68816619 4370.18235    5233.6616     4426.03081667
#  2727.718      2870.7285     3009.0571     2937.69881472 3911.5472
#  4158.7928     2593.70354    4708.5328     4913.7906     2926.3967
6284.52, 4116.03, 1986.53, 3259.9, 4163.52, 4934.49, 4466.66, 1962.4, 4833.4, 3977.39, 1880.24, 3841.76, 2530.76, 2145.37, 4374.01, 3119.81, 1522.83, 2635.25, 5457.48, 2724.22, 4247.4, 4077.79, 4448.53, 1855.27, 5761.13, 5754.67, 3058.32, 1822.77, 4762.24, 1553.54, 6742.24, 3913.14, 2702.28, 4613.81, 1919.72, 2816.89, 2680.78, 2161.15, 2987.61, 2557.79, 5109.27, 2772.63, 2456.42, 1713.06, 5395.22, 3744.31, 2021.64, 4224.56, 4428.58, 3237.4, 3162.49, 3565.04, 4842.4, 3201.52, 4697.15, 4212.03, 4013.02, 3471.13, 3443.18, 3301.85, 3748.76, 2412.38, 3311.14, 3455.11, 3046.08, 4058.74, 5604.49, 2333.24, 3390.69, 3611.96, 4688.99, 3186.28, 6491.63, 3668.57, 5527.62, 2702.87, 3412.17, 3076.64, 5559.23, 2991.09, 1915.84, 5848.18, 3262.56, 3278.02, 3291.81, 2514.66, 3266.1, 3085.91, 4475.58, 3265.55, 3824.59, 4811.78, 2634.0, 1947.09, 3628.52, 2827.98, 2780.16, 1571.43, 3287.64, 4269.91, 2905.57, 3059.76, 3193.24, 3906.17, 6613.77, 2534.9, 3955.7, 4491.46, 2418.76, 1892.08, 3518.02, 1792.49, 2888.45, 3283.24, 4345.32, 4580.92, 3952.09, 1401.3, 3388.03, 3336.36, 2369.94, 1869.17, 2822.57, 4040.98, 1458.05, 3526.28, 3736.56, 3315.59, 2865.12, 2438.83, 3003.32, 3122.48, 4014.16, 5707.89, 2802.47, 4728.18, 1787.21, 4137.38, 4712.73, 4728.99, 4244.55, 3495.79, 3460.06, 3253.88, 1794.98, 3526.39, 2742.01, 2953.49, 5678.01, 4223.59, 3481.76, 2790.88, 3147.46, 5464.39, 2339.36, 5591.96, 5041.39, 5157.19, 2836.73, 1413.96, 3882.93, 3404.77, 5190.53, 3285.97, 1962.0, 3137.51, 3010.54, 2956.04, 3120.74, 2866.27, 2957.43, 4292.88, 2102.73, 3 ...

# %%
Y_test_sub = Y_test[:30]
final_pred_sub = final_pred[:30]
# some_labels=elec_labels.iloc[:100]

plt.figure(figsize=(20, 10))

# Plot actual values
plt.plot(Y_test_sub, label='Actual Values', marker='o')

# Plot predicted values
plt.plot(final_pred_sub, label='Predicted Values', marker='x', linestyle='--')

# Add titles and labels
plt.title('Actual vs Predicted Values')
plt.xlabel('Time Step')
plt.ylabel('Value')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# # SAVING THE MODEL

# %%
from joblib import dump,load
dump(model,'DEPP.joblib')
# Out:
# ['DEPP.joblib']

# %%
prepared_data[:5,:]
# Out:
# array([[ 0.01805363, -0.38421796,  0.35194104, -0.56525144],
#        [ 0.25658433, -0.09859267,  0.86899432, -0.53034059],
#        [ 0.37584967, -0.043472  ,  0.89940922, -0.54732425],
#        [ 0.829058  , -0.13868043,  0.16945165, -0.53034059],
#        [ 0.32814353,  3.13348297, -1.34521031,  1.79264656]])
